# %% [markdown]
# # Laboratory Exercise 1: Introduction to Google Earth Engine (GEE)
# In this lab, you will learn how to initialize Google Earth Engine (GEE), select satellite images, visualize data, and analyze basic metadata.

# %% [markdown]
# ## Task 1: Initialize Google Earth Engine
# Authenticate and initialize the Google Earth Engine (GEE) API.

# %%
# Authenticate and initialize GEE
# TODO: Use the Earth Engine library to authenticate and initialize your session
import ee
ee.Authenticate()
ee.Initialize(project='ee-martynadurda')

# %% [markdown]
# ## Task 2: Define Area of Interest (AOI)
# Define your area of interest (AOI). You can use either a point or a bounding box.
# Example coordinates are provided below (Krakow, Poland). Adjust them for your location.

# %%
# Define AOI
# TODO: Replace with your coordinates
aoi = ee.Geometry.Point([ -3.703790,40.416775])  #madrid
# or
# aoi = ee.Geometry.Rectangle([west, south, east, north])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Task 3: Retrieve Sentinel-2 Data
# Retrieve Sentinel-2 imagery for your defined AOI within a specific date range. Sort the images based on cloud cover percentage.

# %%
# Retrieve Sentinel-2 Data
# TODO: Adjust the date range and retrieve the least cloudy Sentinel-2 image
sentinel2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED').filterBounds(aoi).filterDate('2024-08-15','2024-08-30').sort('CLOUDY_PIXEL_PERCENTAGE')
image = sentinel2.first()
metadata = image.getInfo()
metadata
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32630',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32630',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32630',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B8',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32630',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B8A',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B9',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32630',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'QA10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'QA20',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 4294967295},
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'QA60',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_OPAQUE',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_CIRRUS',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_SNOW_ICE',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32630',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]}],
#  'version': 1742410945257329,
#  'id': 'COPERNICUS/S2_HARMONIZED/20240815T105619_20240815T110512_T30TVK',
#  'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20240815T105619_038873_N05.11',
#   'SPACECRAFT_NAME': 'Sentinel-2B',
#   'RADIO_ADD_OFFSET_B8A': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 102.657493841353,
#   'RADIO_ADD_OFFSET_B10': -1000,
#   'MEAN_SOLAR_AZIMUTH_ANGLE': 145.565938014259,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-4.166147823235735, 39.65584329843554],
#     [-4.166133214187788, 39.65584279931296],
#     [-2.8864531115465666, 39.661641672776874],
#     [-2.8863992003501835, 39.661678175939194],
#     [-2.8863397305844276, 39.66170923086179],
#     [-2.8863360755948455, 39.66172403355885],
#     [-2.884674911923829, 40.65079894911709],
#     [-2.884723034293882, 40.650840465169146],
#     [-2.884763923118124, 40.65088618515677],
#     [-2.8847834157543524, 40.65088902707262],
#     [-4.1831741895315835, 40.644884749194674],
#     [-4.183228190239859, 40.644847693811165],
#     [-4.183287895863246, 40.64481592188686],
#     [-4.183291334409069, 40.644801106748666],
#     [-4.174666059288523, 40.15038449698726],
#     [-4.166251571030126, 39.655931561924234],
#     [-4.166203368904357, 39.655890600521246],
#     [-4.166162276041179, 39.655845296785365],
#     [-4.166147823235735, 39.65584329843554]]},
#   'SOLAR_IRRADIANCE_B12': 87.75,
#   'SOLAR_IRRADIANCE_B10': 365.41,
#   'SENSOR_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B11': 247.08,
#   'GENERATION_TIME': 1723726858000,
#   'RADIO_ADD_OFFSET_B12': -1000,
#   'RADIO_ADD_OFFSET_B11': -1000,
#   'SOLAR_IRRADIANCE_B8A': 953.93,
#   'FORMAT_CORRECTNESS': 'PASSED',
#   'CLOUD_COVERAGE_ASSESSMENT': 0,
#   'system:time_end': 1723720210559,
#   'SNOW_PIXEL_PERCENTAGE': 0,
#   'system:time_start': 1723720210559,
#   'RADIO_ADD_OFFSET_B1': -1000,
#   'RADIO_ADD_OFFSET_B2': -1000,
#   'DATASTRIP_ID': 'S2B_OPER_MSI_L1C_DS_2BPS_20240815T130058_S20240815T110512_N05.11',
#   'RADIO_ADD_OFFSET_B3': -1000,
#   'RADIO_ADD_OFFSET_B4': -1000,
#   'RADIO_ADD_OFFSET_B5': -1000,
#   'PROCESSING_BASELINE': '05.11',
#   'SENSING_ORBIT_NUMBER': 94,
#   'RADIO_ADD_OFFSET_B6': -1000,
#   'RADIO_ADD_OFFSET_B7': -1000,
#   'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#   'GENERAL_QUALITY': 'PASSED',
#   'GRANULE_ID': 'L1C_T30TVK_A038873_20240815T110512',
#   'REFLECTANCE_CONVERSION_CORRECTION': 0.973954826636619,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 104.539507070684,
#   'DATATAKE_TYPE': 'INS-NOBS',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 102.431771201677,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 103.116194954254,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 102.887943299641,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 103.528545082437,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 5.66828231014539,
#   'RADIO_ADD_OFFSET_B8': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 103.335871309202,
#   'RADIOMETRIC_QUALITY': 'PASSED',
#   'RADIO_ADD_OFFSET_B9': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 105.017028059399,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 104.143415003029,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 5.4853542684474,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 102.510697638218,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 5.43893207387529,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 5.3807306638893,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 5.32878252670254,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 5.73333756361075,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 5.35229044972834,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 5.57231583586461,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 5.52984038163677,
#   'MEAN_SOLAR_ZENITH_ANGLE': 30.3030729480085,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 5.61829442928344,
#   'MGRS_TILE': '30TVK',
#   'CLOUDY_PIXEL_PERCENTAGE': 0,
#   'PRODUCT_ID': 'S2B_MSIL1C_20240815T105619_N0511_R094_T30TVK_20240815T130058',
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 5.43049593771631,
#   'SOLAR_IRRADIANCE_B9': 817.58,
#   'DEGRADED_MSI_DATA_PERCENTAGE': 0.0216,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 5.52867580572302,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 5.64738322161456,
#   'SOLAR_IRRADIANCE_B6': 1291.13,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 103.908727441463,
#   'SOLAR_IRRADIANCE_B5': 1425.78,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 103.306582904906,
#   'SOLAR_IRRADIANCE_B8': 1041.28,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 102.905076887345,
#   'SOLAR_IRRADIANCE_B7': 1175.57,
#   'SOLAR_IRRADIANCE_B2': 1959.75,
#   'SOLAR_IRRADIANCE_B1': 1874.3,
#   'SOLAR_IRRADIANCE_B4': 1512.79,
#   'GEOMETRIC_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B3': 1824.93,
#   'system:asset_size': 1392957928,
#   'system:index': '20240815T105619_20240815T110512_T30TVK'}}

# %% [markdown]
# ## Task 4: Extract Image Metadata
# Extract and print metadata from the selected image, such as ID, cloud cover percentage, mean solar azimuth and zenith angles, and processing level.

# %%
# Extract metadata
# TODO: Retrieve and display image metadata
metadata = {
    "Image ID": image.get("system:index").getInfo(),
    "Cloud Cover Percentage": image.get("CLOUDY_PIXEL_PERCENTAGE").getInfo(),
    "Mean Solar Azimuth Angle": image.get("MEAN_SOLAR_AZIMUTH_ANGLE").getInfo(),
    "Mean Solar Zenith Angle": image.get("MEAN_SOLAR_ZENITH_ANGLE").getInfo(),
    "Processing Level": image.get("PROCESSING_BASELINE").getInfo()
}

for key, value in metadata.items():
    print(f"{key}: {value}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Image ID: 20240815T105619_20240815T110512_T30TVK
# Cloud Cover Percentage: 0
# Mean Solar Azimuth Angle: 145.565938014259
# Mean Solar Zenith Angle: 30.3030729480085
# Processing Level: 05.11

# %% [markdown]
# ## Task 5: Visualize Image
# Create a map and visualize the Sentinel-2 image using different visualization parameters (e.g., true color, false color).

# %%
# Visualization
# TODO: Create visualization layers using true color and false color compositions
# Example parameters provided below:
true_color_params = {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}
false_color_params = {'bands': ['B8', 'B4', 'B3'], 'min': 0, 'max': 5000}

# TODO: Add these layers to an interactive map
import geemap

Map = geemap.Map(center=[-3.703790,40.416775], zoom=10)
Map.addLayer(image, true_color_params, "True Color (RGB)")
Map.addLayer(image, false_color_params, "False Color (NIR)")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40.7128, -74.006], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDa…

# %% [markdown]
# ## Submission
# Save your completed notebook and submit it to your course repository.
